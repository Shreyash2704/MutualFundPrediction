# %%
import pandas as pd

# %%
df = pd.read_excel("SchemeFile_10_13_2022_10_7_29.xlsx")

# %%
df.head()
# Out:
#                      FundName  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  SBI Magnum Equity ESG Fund         NaN         NaN         NaN         NaN
# 1  SBI Magnum Equity ESG Fund         NaN         NaN         NaN         NaN
# 2  SBI Magnum Equity ESG Fund         NaN         NaN         NaN         NaN
# 3  SBI Magnum Equity ESG Fund         NaN         NaN         NaN         NaN
# 4  SBI Magnum Equity ESG Fund         NaN         NaN         NaN         NaN
#
#                                           SchemeName  Unnamed: 6  Unnamed: 7  \
# 0  SBI Magnum Equity ESG Fund - Regular Plan - ID...         NaN         NaN
# 1  SBI Magnum Equity ESG Fund - Regular Plan - ID...         NaN         NaN
# 2  SBI Magnum Equity ESG Fund - Regular Plan - ID...         NaN         NaN
# 3  SBI Magnum Equity ESG Fund - Regular Plan - ID...         NaN         NaN
# 4  SBI Magnum Equity ESG Fund - Regular Plan - ID...         NaN         NaN
#
# ...

# %%
newdf = df[["FundName","NAV_DATE","NAV"]].copy(deep=True)

# %%
newdf
# Out:
#                        FundName     NAV_DATE      NAV
# 0    SBI Magnum Equity ESG Fund  12-Oct-2022  50.1837
# 1    SBI Magnum Equity ESG Fund  11-Oct-2022  49.8047
# 2    SBI Magnum Equity ESG Fund  10-Oct-2022  50.5368
# 3    SBI Magnum Equity ESG Fund  07-Oct-2022  50.7732
# 4    SBI Magnum Equity ESG Fund  06-Oct-2022  50.7844
# ..                          ...          ...      ...
# 490  SBI Magnum Equity ESG Fund  19-Oct-2020  34.0014
# 491  SBI Magnum Equity ESG Fund  16-Oct-2020  33.8624
# 492  SBI Magnum Equity ESG Fund  15-Oct-2020  33.5264
# 493  SBI Magnum Equity ESG Fund  14-Oct-2020  34.3243
# 494  SBI Magnum Equity ESG Fund  13-Oct-2020  34.2015
#
# [495 rows x 3 columns]

# %%
#newdf["NAV_DATE"] = pd.to_datetime(newdf["NAV_DATE"], format = "%Y-%m-%d")

# %%
l = list(newdf["NAV_DATE"])
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
c = 0
newl = []
for i in l:
    m = i.split("-")
    m[1] = str(month.index(m[1])+1)
    m = m[::-1]
    s = "-".join(m)
    newl.append(s)
newdf["NAV_DATE"] = newl

# %%
df2 = pd.read_excel("SchemeFile_10_14_2022_1_6_44.xlsx")

# %%
df2 = df2[["FundName","NAV_DATE","NAV"]].copy(deep=True)
df2
# Out:
#                     FundName     NAV_DATE       NAV
# 0    SBI Large & Midcap Fund  13-Oct-2022  173.4875
# 1    SBI Large & Midcap Fund  12-Oct-2022  174.6845
# 2    SBI Large & Midcap Fund  11-Oct-2022  174.3058
# 3    SBI Large & Midcap Fund  10-Oct-2022  176.1708
# 4    SBI Large & Midcap Fund  07-Oct-2022  177.2006
# ..                       ...          ...       ...
# 490  SBI Large & Midcap Fund  20-Oct-2020  100.4323
# 491  SBI Large & Midcap Fund  19-Oct-2020   99.9021
# 492  SBI Large & Midcap Fund  16-Oct-2020   99.0499
# 493  SBI Large & Midcap Fund  15-Oct-2020   97.8279
# 494  SBI Large & Midcap Fund  14-Oct-2020   99.6307
#
# [495 rows x 3 columns]

# %%
l = list(df2["NAV_DATE"])
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
c = 0
newl = []
for i in l:
    m = i.split("-")
    m[1] = str(month.index(m[1])+1)
    m = m[::-1]
    s = "-".join(m)
    newl.append(s)
df2["NAV_DATE"] = newl
df2
# Out:
#                     FundName    NAV_DATE       NAV
# 0    SBI Large & Midcap Fund  2022-10-13  173.4875
# 1    SBI Large & Midcap Fund  2022-10-12  174.6845
# 2    SBI Large & Midcap Fund  2022-10-11  174.3058
# 3    SBI Large & Midcap Fund  2022-10-10  176.1708
# 4    SBI Large & Midcap Fund  2022-10-07  177.2006
# ..                       ...         ...       ...
# 490  SBI Large & Midcap Fund  2020-10-20  100.4323
# 491  SBI Large & Midcap Fund  2020-10-19   99.9021
# 492  SBI Large & Midcap Fund  2020-10-16   99.0499
# 493  SBI Large & Midcap Fund  2020-10-15   97.8279
# 494  SBI Large & Midcap Fund  2020-10-14   99.6307
#
# [495 rows x 3 columns]

# %%
frames = [newdf, df2]
mergedf = pd.concat(frames)
mergedf
# Out:
#                        FundName    NAV_DATE       NAV
# 0    SBI Magnum Equity ESG Fund  2022-10-12   50.1837
# 1    SBI Magnum Equity ESG Fund  2022-10-11   49.8047
# 2    SBI Magnum Equity ESG Fund  2022-10-10   50.5368
# 3    SBI Magnum Equity ESG Fund  2022-10-07   50.7732
# 4    SBI Magnum Equity ESG Fund  2022-10-06   50.7844
# ..                          ...         ...       ...
# 490     SBI Large & Midcap Fund  2020-10-20  100.4323
# 491     SBI Large & Midcap Fund  2020-10-19   99.9021
# 492     SBI Large & Midcap Fund  2020-10-16   99.0499
# 493     SBI Large & Midcap Fund  2020-10-15   97.8279
# 494     SBI Large & Midcap Fund  2020-10-14   99.6307
#
# [990 rows x 3 columns]

# %%
return_sbi_magnum = ( list(df2["NAV"])[0] - list(df2["NAV"])[-1] )/( list(df2["NAV"])[-1])
print(list(df2["NAV"])[0],list(df2["NAV"])[-1])
return_sbi_magnum*100
# Out:
# 173.4875 99.6307
# 74.1305641734927

# %%
newdf.tail()
# Out:
#                        FundName    NAV_DATE      NAV
# 490  SBI Magnum Equity ESG Fund  2020-10-19  34.0014
# 491  SBI Magnum Equity ESG Fund  2020-10-16  33.8624
# 492  SBI Magnum Equity ESG Fund  2020-10-15  33.5264
# 493  SBI Magnum Equity ESG Fund  2020-10-14  34.3243
# 494  SBI Magnum Equity ESG Fund  2020-10-13  34.2015

# %%
mergedf.to_excel("merge_magnum_midcap.xlsx")

# %%
index = []
for i in range(990):
    index.append(i+1)
mergedf.set_index(index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-bf4499ddda3f> in <module>
#       2 for i in range(990):
#       3     index.append(i+1)
# ----> 4 mergedf.set_index(index)
#
# ~\miniconda3\envs\tensorflow_gpuenv\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# ...

# %%
mergedf = mergedf.reset_index()

# %% [raw]
# mergedf

# %%
mergedf
# Out:
#      index                    FundName    NAV_DATE       NAV
# 0        0  SBI Magnum Equity ESG Fund  2022-10-12   50.1837
# 1        1  SBI Magnum Equity ESG Fund  2022-10-11   49.8047
# 2        2  SBI Magnum Equity ESG Fund  2022-10-10   50.5368
# 3        3  SBI Magnum Equity ESG Fund  2022-10-07   50.7732
# 4        4  SBI Magnum Equity ESG Fund  2022-10-06   50.7844
# ..     ...                         ...         ...       ...
# 985    490     SBI Large & Midcap Fund  2020-10-20  100.4323
# 986    491     SBI Large & Midcap Fund  2020-10-19   99.9021
# 987    492     SBI Large & Midcap Fund  2020-10-16   99.0499
# 988    493     SBI Large & Midcap Fund  2020-10-15   97.8279
# 989    494     SBI Large & Midcap Fund  2020-10-14   99.6307
#
# [990 rows x 4 columns]

# %%
df = pd.read_excel(r"SBI Equity Hybrid Fund.xlsx")

# %%
df = df[["NAV_DATE","NAV"]].copy(deep=True)

# %%
df
# Out:
#         NAV_DATE      NAV
# 0    17-Oct-2022  43.3046
# 1    14-Oct-2022  43.1404
# 2    13-Oct-2022  42.9276
# 3    12-Oct-2022  43.1012
# 4    11-Oct-2022  42.9650
# ..           ...      ...
# 489  23-Oct-2020  30.2318
# 490  22-Oct-2020  30.1818
# 491  21-Oct-2020  30.1594
# 492  20-Oct-2020  30.0893
# 493  19-Oct-2020  30.0402
#
# [494 rows x 2 columns]

# %%
l = list(df["NAV_DATE"])
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
c = 0
newl = []
for i in l:
    m = i.split("-")
    m[1] = str(month.index(m[1])+1)
    m = m[::-1]
    s = "-".join(m)
    newl.append(s)
df["NAV_DATE"] = newl
df
# Out:
#        NAV_DATE      NAV
# 0    2022-10-17  43.3046
# 1    2022-10-14  43.1404
# 2    2022-10-13  42.9276
# 3    2022-10-12  43.1012
# 4    2022-10-11  42.9650
# ..          ...      ...
# 489  2020-10-23  30.2318
# 490  2020-10-22  30.1818
# 491  2020-10-21  30.1594
# 492  2020-10-20  30.0893
# 493  2020-10-19  30.0402
#
# [494 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = df["NAV_DATE"]
y = df["NAV"]

# plot
fig, ax = plt.subplots()

ax.plot(x, y)

plt.show()

# %%
columns1 =  df["NAV_DATE"].tolist()
columns2 = df["NAV"].tolist()

# %%
columns1 = columns1[::-1]
columns2 = columns2[::-1]

# %%
df["NAV_DATE"] = columns1
df["NAV"] = columns2

# %%
X = np.array(df['NAV_DATE']).reshape(-1, 1)
y = np.array(df['NAV']).reshape(-1, 1)

# %%
df.dropna(inplace = True)

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression()
  
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-65eb03dd044e> in <module>
#       1 regr = LinearRegression()
#       2
# ----> 3 regr.fit(X_train, y_train)
#       4 print(regr.score(X_test, y_test))
#
# ~\miniconda3\envs\tensorflow_gpuenv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\miniconda3\envs\tensorflow_gpuenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
type(X[0])
# Out:
# numpy.ndarray

# %%
def encode(data, col, max_val):
    data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
    data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
    return data

# %%
data['month'] = data.datetime.dt.month
data = encode(data, 'month', 12)

data['day'] = data.datetime.dt.day
data = encode(data, 'day', 31)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-b86e81a24e25> in <module>
# ----> 1 data['month'] = data.datetime.dt.month
#       2 data = encode(data, 'month', 12)
#       3
#       4 data['day'] = data.datetime.dt.day
#       5 data = encode(data, 'day', 31)
#
# NameError: name 'data' is not defined
